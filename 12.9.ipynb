# %%
from statsmodels.datasets import get_rdataset
USArrests = get_rdataset('USArrests').data
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import (KMeans ,AgglomerativeClustering)
from scipy.cluster.hierarchy import (dendrogram ,cut_tree)
from ISLP.cluster import compute_linkage
from sklearn.preprocessing import StandardScaler

# %%
#a
HClust = AgglomerativeClustering
hc_comp = HClust(distance_threshold=0,n_clusters=None ,linkage='complete')
hc_comp.fit(USArrests)


cargs = {'color_threshold':-np.inf ,'above_threshold_color':'black'}
linkage_comp = compute_linkage(hc_comp)
fig , ax = plt.subplots(1, 1, figsize=(8, 8))
dendrogram(linkage_comp ,ax=ax,**cargs);

# %%
#b
clusters = cut_tree(linkage_comp , n_clusters=3)
USArrests['cluster'] = clusters
cl = USArrests.drop(columns=['Rape','UrbanPop','Murder','Assault'])
cl
# Out:
#                 cluster
# rownames
# Alabama               0
# Alaska                0
# Arizona               0
# Arkansas              1
# California            0
# Colorado              1
# Connecticut           2
# Delaware              0
# Florida               0
# Georgia               1
# Hawaii                2
# Idaho                 2
# Illinois              0
# Indiana               2
# Iowa                  2
# Kansas                2
# Kentucky              2
# Louisiana             0
# Maine                 2
# Maryland              0
# Massachusetts         1
# Michigan              0
# Minnesota             2
# Mississippi           0
# Missouri              1
# Montana               2
# Nebraska              2
# Nevada                0
# New Hampshire         2
# New Jersey            1
# New Mexico            0
# New York              0
# North Carolina        0
# North Dakota          2
# Ohio                  2
# Oklahoma              1
# Oregon                1
# Pennsylvania          2
# Rhode Island          1
# South Carolina        0
# South Dakota          2
# Tennessee             1
# Texas                 1
# Utah                  2
# Vermont               2
# Virginia              1
# Washington            1
# West Virginia         2
# Wisconsin             2
# Wyoming               1

# %%
#c
scaler = StandardScaler(with_std=True ,with_mean=True)
USArrests_scaled = scaler.fit_transform(USArrests)


HClust = AgglomerativeClustering
hc_comp = HClust(distance_threshold=0,n_clusters=None ,linkage='complete')
hc_comp.fit(USArrests_scaled)


cargs = {'color_threshold':-np.inf ,'above_threshold_color':'black'}
linkage_comp = compute_linkage(hc_comp)
fig , ax = plt.subplots(1, 1, figsize=(8, 8))
dendrogram(linkage_comp ,ax=ax,**cargs);

# %%
#d
clusters_scaled = cut_tree(linkage_comp , n_clusters=3)
cl['cluster_scaled'] = clusters_scaled
cl
# Out:
#                 cluster  cluster_scaled
# rownames
# Alabama               0               0
# Alaska                0               0
# Arizona               0               0
# Arkansas              1               1
# California            0               0
# Colorado              1               0
# Connecticut           2               1
# Delaware              0               1
# Florida               0               0
# Georgia               1               0
# Hawaii                2               1
# Idaho                 2               2
# Illinois              0               0
# Indiana               2               1
# Iowa                  2               2
# Kansas                2               1
# Kentucky              2               1
# Louisiana             0               0
# Maine                 2               2
# Maryland              0               0
# Massachusetts         1               1
# Michigan              0               0
# Minnesota             2               1
# Mississippi           0               0
# Missouri              1               0
# Montana               2               2
# Nebraska              2               2
# Nevada                0               0
# New Hampshire         2               2
# New Jersey            1               1
# New Mexico            0               0
# New York              0               0
# North Carolina        0               0
# North Dakota          2               2
# Ohio                  2               1
# Oklahoma              1               1
# Oregon                1               0
# Pennsylvania          2               1
# Rhode Island          1               1
# South Carolina        0               0
# South Dakota          2               2
# Tennessee             1               0
# Texas                 1               0
# Utah                  2               1
# Vermont               2               2
# Virginia              1               1
# Washington            1               0
# West Virginia         2               2
# Wisconsin             2               1
# Wyoming               1               1
