# %%
#10.a

import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from ISLP import load_data
#os.getcwd()
os.chdir('D:\\Uni\\Courses\\ML\\ALL CSV FILES - 2nd Edition')
Boston = load_data('Boston')

# %%
#10.b
print('rows = ', Boston.shape[0])
print('columns = ', Boston.shape[1])
Boston
# Out:
# rows =  506
# columns =  13
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# ...

# %%
#10.c

C = ['crim', 'zn', 'indus','chas', 'nox', 'rm','age', 'dis', 'rad', 'tax', 'ptratio', 'lstat', 'medv']
pd.plotting.scatter_matrix(Boston[C])
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='zn', ylabel='crim'>,
#         <Axes: xlabel='indus', ylabel='crim'>,
#         <Axes: xlabel='chas', ylabel='crim'>,
#         <Axes: xlabel='nox', ylabel='crim'>,
#         <Axes: xlabel='rm', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='rad', ylabel='crim'>,
#         <Axes: xlabel='tax', ylabel='crim'>,
#         <Axes: xlabel='ptratio', ylabel='crim'>,
#         <Axes: xlabel='lstat', ylabel='crim'>,
#         <Axes: xlabel='medv', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='zn'>,
#         <Axes: xlabel='zn', ylabel='zn'>,
#         <Axes: xlabel='indus', ylabel='zn'>,
#         <Axes: xlabel='chas', ylabel='zn'>,
#         <Axes: xlabel='nox', ylabel='zn'>,
#         <Axes: xlabel='rm', ylabel='zn'>,
#         <Axes: xlabel='age', ylabel='zn'>,
#         <Axes: xlabel='dis', ylabel='zn'>,
# ...

# %%
#10.d
fig, axes = plt.subplots(nrows=13, ncols=1, figsize=(20,100))

for col, ax in zip(C, axes):
    Boston.plot(kind='scatter', x=col, y='crim', ax=ax)
#Boston.plot.scatter(x=C,y=C)

# %%
#10.f

print(Boston['chas'].value_counts())
# Out:
# 0    471
# 1     35
# Name: chas, dtype: int64

# %%
#10.g
Boston['ptratio'].median()
# Out:
# 19.05

# %%
#10.h
print(Boston['medv'].idxmin())
print(Boston.loc[398])
Boston.describe()
# Out:
# 398
# crim        38.3518
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6930
# rm           5.4530
# age        100.0000
# dis          1.4896
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# lstat       30.5900
# medv         5.0000
# Name: 398, dtype: float64
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# ...

# %%
#10.i
count7 = (Boston['rm']>7).sum()
print('more than 7 = ',count7)
count8 = (Boston['rm']>8).sum()
print('more than 8 = ', count8)
sorted = Boston.sort_values(by='rm', ascending=False)
sorted = sorted.reset_index(drop=True)
sorted.loc[0:12]
# Out:
# more than 7 =  64
# more than 8 =  13
#        crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 0   3.47428   0.0  18.10     1  0.7180  8.780  82.9  1.9047   24  666
# 1   0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 2   0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 3   0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 4   1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 5   0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 6   0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# 7   0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 8   0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 9   0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 10  0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 11  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# ...
